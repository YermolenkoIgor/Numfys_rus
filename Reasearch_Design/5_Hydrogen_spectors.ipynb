# %%
using Plots, DelimitedFiles

# %%
dats = readdlm("HD164257_av.dat");
size(dats)
# Out:
# (3682, 3)

# %%
x = dats[:,1]
y = dats[:,2]
y2 = dats[:,3]
plot(x, y)
plot!(x, y2)
# Out:
# ┌ Info: Precompiling GR_jll [d2c73de3-f751-5644-a686-071e5b155ba9]
# └ @ Base loading.jl:1278

# %% [markdown]
# 1. Найти статью *MUSE library of stellar spectra A&A 629, A100 (2019)*. Там приведена ссылка на базу данных спектров различных звезд. Выберите себе одну и скачайте соответствующий файл *.dat*
# 1. Организуйте считывание данных из файла, постройте графики, подпишите оси и единицы измерения
# 1. Реализуйте формулу нахождения уровней энергии атома водорода. Проследите, чтобы единицы измерения совпадали для соответствующих величин из базы спектров.
# 1. Наложите уровни энергии переходов в атоме водорода на спектр звезды. Объясните результат.
# ----
# * Найдите дополнительную информацию о выбранной вами звезде.
# * Сопоставьте со спектром звезды линии переходов других химических элементов ([Пример 1](http://umop.net/spectra/
# ), [Пример 2](https://www.nist.gov/pml/atomic-spectra-database))
# * Установите о опробуйте работу пакета для языка Python [PyHammer](https://github.com/BU-hammerTeam/PyHammer)

# %% [markdown]
# ![img](images/img_spec.png)
#
# $$
# E_0 = -\frac{m_e e^4}{8h^2\varepsilon^2_0}
# $$
#
# $$
# E_{nj} = \frac{E_0}{n^2}\left( 1 + \frac{\alpha^2}{n^2} \left( \frac{n}{j + \frac 1 2} - \frac 3 4 \right) \right)
# $$

# %%
const α =  
const c =  
const ħ =  
const h =  
const e =  
const mₑ = 
const ε₀ = 
const E₀ =

# %%
j = 0

En(n) = ##

# %%
Ens = [ ###En(n)*#### for n in ### ]

# %%
vline(Ens)
